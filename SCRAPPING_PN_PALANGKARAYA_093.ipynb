# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee7c5622e5dc1c90dd313033393438.html'

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

soup.find('table')
soup.find_all('table')

soup.find('table', class_ = 'table')
table = soup.find_all('table')

world_titles = soup.find_all('td', class_ = 'text-right')
world_table_titles = [title.text.strip() for title in world_titles]

df = pd.DataFrame(columns = world_table_titles)
column_data = soup.find_all('tr')

# Inisialisasi list kosong untuk kolom data
kolom_data = [[] for _ in range(19)]

# Mengiterasi melalui baris data
for row in column_data[1:19]:
    # Mengambil semua elemen 'td' dalam baris
    row_data = row.find_all('td')

    # Mengambil teks dari setiap 'td' dan memasukkannya ke dalam kolom yang sesuai
    for i, data in enumerate(row_data):
        if 'text-right' not in data.get('class', []):
            kolom_data[i].append(data.text.strip())

# Menghapus kolom yang kosong
kolom_data = [kolom for kolom in kolom_data if kolom]

# Cetak data dalam bentuk kolom
for kolom in kolom_data:
    print(kolom)

length = len(df)
df.loc[length] = kolom
# Out:
# ['208/PID.SUS/2023/PT PLK', 'Banding', 'Pidana Khusus  Narkotika dan Psikotropika \n Pidana Khusus  Narkotika dan Psikotropika', 'Narkotika', '2023', '18 Oktober 2023', 'PT PALANGKARAYA', 'PT', 'Diris Sinambela', 'Djoko Indiarto, Brheru Budyanto', 'Bambang Sukino', 'Lain-lain', 'M E N G A D I L I : MENERIMA PERMINTAAN BANDING DARI PENUNTUT UMUM TERSEBUT; MENGUATKAN PUTUSAN PENGADILAN NEGERI KUALA KAPUAS NOMOR 167/PID.SUS/2023/PN KLK TANGGAL 25 OKTOBER 2023 YANG DIMINTAKAN BANDING TERSEBUT ; MENETAPKAN AGAR TERDAKWA TETAP BERADA DALAM TAHANAN ; MENETAPKAN MASA PENANGKAPAN DAN PENAHANAN YANG TELAH DIJALANI TERDAKWA DIKURANGKAN SELURUHNYA DARI PIDANA YANG DIJATUHKAN; MEMBEBANKAN BIAYA PERKARA KEPADA TERDAKWA DALAM DUA TINGKAT PERADILAN, YANG DALAM TINGKAT BANDING SEJUMLAH RP2.500,00 (DUA RIBU LIMA RATUS RUPIAH);', 'M E N G A D I L I : Menerima permintaan banding dari Penuntut Umum tersebut; Menguatkan putusan Pengadilan Negeri Kuala Kapuas Nomor 167/Pid.Sus/2023/PN Klk tanggal 25 Oktobe
# ...

# %%
def get_data(url):
  page = requests.get(url)
  soup = BeautifulSoup(page.text, 'html')

  column_data = soup.find_all('tr')

  # Inisialisasi list kosong untuk kolom data
  kolom_data = [[] for _ in range(19)]
  page = requests.get(url)
  soup = BeautifulSoup(page.text, 'html')

  column_data = soup.find_all('tr')

  # Inisialisasi list kosong untuk kolom data
  kolom_data = [[] for _ in range(19)]

  # Mengiterasi melalui baris data
  for row in column_data[1:19]:
      # Mengambil semua elemen 'td' dalam baris
      row_data = row.find_all('td')

    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee1ba891b9bda2b956303935353330.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee1ba3cc16de1cbec4303932313231.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee1af75ce9387a9563313234373031.html',
    'https://putusan3.mahkamahagung.go.id/direktori/putusan/zaee1ae405fc5aa083e3313032383335.html',
]

for url in urls:
  get_data(url)
# Out:
# ['196/PID.SUS/2023/PT PLK', 'Banding', 'Pidana Khusus  Narkotika dan Psikotropika \n Pidana Khusus  Narkotika dan Psikotropika', 'Narkotika', '2023', '11 Oktober 2023', 'PT PALANGKARAYA', 'PT', 'Abdul Rauf', 'Didit Susilo Guntono, Brsuharno', 'Linda', 'Lain-lain', 'M E N G A D I L I MENERIMA PERMINTAAN BANDING DARI TERDAKWA TERSEBUT; MENGUBAH PUTUSAN PENGADILAN NEGERI MUARA TEWEH NOMOR 93/PID.SUS/2023/PN MTW TANGGAL 18 SEPTEMBER 2023 YANG DIMINTAKAN BANDING MENGENAI LAMANYA PIDANA PENJARA YANG DIJATUHKAN KEPADA TERDAKWA SEHINGGA AMAR SELENGKAPNYA BERBUNYI SEBAGAI BERIKUT: MENYATAKAN TERDAKWA SUJARWO ALIAS JARWO BIN MUJIRAN TELAH TERBUKTI SECARA SAH DAN MEYAKINKAN BERSALAH MELAKUKAN TINDAK PIDANA TANPA HAK ATAU MELAWAN HUKUM MENERIMA NARKOTIKA GOLONGAN I SEBAGAIMANA DALAM DAKWAAN ALTERNATIF KESATU; MENJATUHKAN PIDANA TERHADAP TERDAKWA SUJARWO ALIAS JARWO BIN MUJIRAN DENGAN PIDANA PENJARA SELAMA 6 (ENAM) TAHUN DAN 6 (ENAM) BULAN SERTA PIDANA DENDA SEJUMLAH RP1.000.000.000,00 (SATU MILI
# ...

# %%
df.head()
# Out:
#                      Nomor Tingkat Proses  \
# 0  208/PID.SUS/2023/PT PLK        Banding
# 1  196/PID.SUS/2023/PT PLK        Banding
# 2  200/PID.SUS/2023/PT PLK        Banding
# 3  201/PID.SUS/2023/PT PLK        Banding
# 4  197/PID.SUS/2023/PT PLK        Banding
#
#                                          Klasifikasi  \
# 0  Pidana Khusus  Narkotika dan Psikotropika \n P...
# 1  Pidana Khusus  Narkotika dan Psikotropika \n P...
# 2  Pidana Khusus  Narkotika dan Psikotropika \n P...
# 3  Pidana Khusus \n Pidana Khusus  Perdagangan Orang
# 4  Pidana Khusus  Narkotika dan Psikotropika \n P...
#
#                                       Kata Kunci Tahun Tanggal Register  \
# 0                                      Narkotika  2023  18 Oktober 2023
# 1                                      Narkotika  2023  11 Oktober 2023
# 2                                      Narkotika  2023  12 Oktober 2023
# 3  Pemberantasan Tindak Pidana Perdagangan Orang  2023  12 Oktober 2023
# ...

# %%
df.to_csv('pn_palangkaraya.csv', index = False)
